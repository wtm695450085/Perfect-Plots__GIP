# %% [markdown]
# # Perfect Plots: Joyplot Plot

# %%
# %load_ext nb_black
# %load_ext pycodestyle_magic
# %pycodestyle_on

# %%
import joypy
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Car market analysis
# Source of data: https://github.com/selva86/datasets/blob/master/mpg_ggplot2.csv

# %% [markdown]
# GSuite Text and Background Palette: https://yagisanatode.com/2019/08/06/google-apps-script-hexadecimal-color-codes-for-google-docs-sheets-and-slides-standart-palette/

# %%
df = pd.read_csv("/media/wojciech/D6DE33C1DE339927/1A/autos.csv")
df.head()
# Out:
#    Unnamed: 0  symboling  normalized_losses         make fuel_type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num_doors   body_style drive_wheels engine_location  ...  engine_size  \
# 0       two  convertible          rwd           front  ...          130
# 1       two  convertible          rwd           front  ...          130
# 2       two    hatchback          rwd           front  ...          152
# 3      four        sedan          fwd           front  ...          109
# 4      four        sedan          4wd           front  ...          136
#
#    fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  city_mpg  \
# 0         mpfi  3.47    2.68                9.0      111.0   5000.0        21
# 1         mpfi  3.47    2.68                9.0      111.0   5000.0        21
# 2         mpfi  2.68    3.47                9.0      154.0   5000.0        19
# 3         mpfi  3.19    3.40               10.0      102.0   5500.0        24
# 4         mpfi  3.19    3.40                8.0      115.0   5500.0        18
#
#   highway_mpg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 27 columns]

# %%
def N_plots(df, x1, x2, by, title, x_title):

    plt.figure(dpi=380)

    fig, axes = joypy.joyplot(
        df,
        column=[x1, x2],
        by=by,
        ylim="own",
        figsize=(12, 8),
        legend=True,
        color=["#f4cccc", "#0c343d"],
        alpha=0.4,
    )
    # color=['#76a5af', '#134f5c']
    # color=['#f4cccc', '#0c343d']
    # color=['#a4c2f4', '#1c4587']
    # color=['#e06666', '#d9d9d9']
    # color=['#e06666', '#434343']
    # color=['#b6d7a8','#6aa84f']

    # Decoration
    plt.title(title, fontsize=32, color="#d0e0e3", alpha=0.9)
    plt.rc("font", size=20)
    plt.xlabel(x_title, fontsize=16, color="darkred", alpha=1)
    # plt.ylabel('Data Scientist', fontsize=26,  color='grey', alpha=0.8)

    plt.show

# %%
df4 = df[["body_style", "highway_mpg", "city_mpg"]]
df4.head()
# Out:
#     body_style  highway_mpg  city_mpg
# 0  convertible           27        21
# 1  convertible           27        21
# 2    hatchback           26        19
# 3        sedan           30        24
# 4        sedan           22        18

# %%
df = df
x1 = "highway_mpg"
x2 = "city_mpg"
by = "body_style"
title = "Fuel consumption by body style"
x_title = "Fuel consumption"

N_plots(df, x1, x2, by, title, x_title)

# %% [markdown]
# ### Joyplot Plot by class designer

# %%
class N_plot:
    def __init__(self, df, x1, x2, by, title, x_title):
        self.df = df
        self.x1 = x1
        self.x2 = x2
        self.by = by
        self.title = title
        self.x_title = x_title

    def plot(self):
        plt.figure(dpi=380)
        fig, axes = joypy.joyplot(
            df,
            column=[x1, x2],
            by=by,
            ylim="own",
            figsize=(12, 8),
            legend=True,
            color=["#e06666", "#d9d9d9"],
            alpha=0.4,
        )
        plt.title(title, fontsize=32, color="#d0e0e3", alpha=0.9)
        plt.rc("font", size=20)
        plt.xlabel(x_title, fontsize=16, color="darkred", alpha=1)


import matplotlib.pyplot as plt

plt.figure(dpi=380)
# color=['#76a5af', '#134f5c']
# color=['#f4cccc', '#0c343d']
# color=['#a4c2f4', '#1c4587']
# color=['#e06666', '#d9d9d9']
# color=['#e06666', '#434343']
# color=['#b6d7a8','#6aa84f']
# Out:
# 27:1: E402 module level import not at top of file

# %%
df = df
x1 = "highway_mpg"
x2 = "city_mpg"
by = "body_style"
title = "Fuel consumption by body style"
x_title = "Fuel consumption"

kot = N_plot(df, x1, x2, by, title, x_title)

# %%
kot.plot()

# %% [markdown]
# ## Titanic disaster
# We ought to find which passengers have chance to survive according to their affiliation to the established groups.
#
# Source of data: https://www.kaggle.com/shivamp629/traincsv

# %%
df2 = pd.read_csv("/media/wojciech/D6DE33C1DE339927/1A/kaggletrain.csv")
df2.head(3)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df2["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
AA = df2.pivot_table(
    index=["Name", "Pclass"], columns="Sex", values="Age"
).reset_index()
AA.head()
# Out:
# Sex                                   Name  Pclass  female  male
# 0                      Abbing, Mr. Anthony       3     NaN  42.0
# 1              Abbott, Mr. Rossmore Edward       3     NaN  16.0
# 2         Abbott, Mrs. Stanton (Rosa Hunt)       3    35.0   NaN
# 3                      Abelson, Mr. Samuel       2     NaN  30.0
# 4    Abelson, Mrs. Samuel (Hannah Wizosky)       2    28.0   NaN
# 1:35: E231 missing whitespace after ','
# 1:80: E501 line too long (88 > 79 characters)

# %%
df = AA
x1 = "female"
x2 = "male"
by = "Pclass"
title = "Titanic disaster: age distribution of casualties by the class"
x_title = "Age of passengers"

pks = N_plot(df, x1, x2, by, title, x_title)
pks.plot()
# Out:
# 1:3: E225 missing whitespace around operator
# 2:3: E225 missing whitespace around operator
# 3:3: E225 missing whitespace around operator
# 4:3: E225 missing whitespace around operator
# 8:16: E231 missing whitespace after ','
# 8:19: E231 missing whitespace after ','
# 8:22: E231 missing whitespace after ','
# 8:25: E231 missing whitespace after ','

# %%
BB = df2.pivot_table(
    index=["Name", "Survived"], columns="Sex", values="Age"
).reset_index()
BB.head()
# Out:
# Sex                                   Name  Survived  female  male
# 0                      Abbing, Mr. Anthony         0     NaN  42.0
# 1              Abbott, Mr. Rossmore Edward         0     NaN  16.0
# 2         Abbott, Mrs. Stanton (Rosa Hunt)         1    35.0   NaN
# 3                      Abelson, Mr. Samuel         0     NaN  30.0
# 4    Abelson, Mrs. Samuel (Hannah Wizosky)         1    28.0   NaN
# 1:35: E231 missing whitespace after ','
# 1:80: E501 line too long (90 > 79 characters)

# %%
df = BB
x1 = "female"
x2 = "male"
by = "Survived"
title = "Titanic disaster: age distribution of casualties by the Survived"
x_title = "Age of passengers"

ZHP = N_plot(df, x1, x2, by, title, x_title)
ZHP.plot()
# Out:
# 1:3: E225 missing whitespace around operator
# 2:3: E225 missing whitespace around operator
# 3:3: E225 missing whitespace around operator
# 4:3: E225 missing whitespace around operator
# 8:16: E231 missing whitespace after ','
# 8:19: E231 missing whitespace after ','
# 8:22: E231 missing whitespace after ','
# 8:25: E231 missing whitespace after ','

# %% [markdown]
# ## Drinks by Country
#
# Source of data: https://github.com/fivethirtyeight/data/blob/master/alcohol-consumption/drinks.csv

# %%
df3 = pd.read_csv("/media/wojciech/D6DE33C1DE339927/1A/drinksbycountry.csv")
df3.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
# 2           2      Algeria             25                0             14
# 3           3      Andorra            245              138            312
# 4           4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
class N_plot3:
    def __init__(self, df, x1, x2, x3, by, title, x_title):
        self.df = df
        self.x1 = x1
        self.x2 = x2
        self.x3 = x3
        self.by = by
        self.title = title
        self.x_title = x_title

    def plot(self):
        plt.figure(dpi=380)
        fig, axes = joypy.joyplot(
            df,
            column=[x1, x2, x3],
            by=by,
            ylim="own",
            figsize=(12, 8),
            legend=True,
            color=["#b6d7a8", "#1c4587", "#6aa84f"],
            alpha=0.4,
        )
        plt.title(title, fontsize=32, color="#d0e0e3", alpha=0.9)
        plt.rc("font", size=20)
        plt.xlabel(x_title, fontsize=16, color="darkred", alpha=1)


import matplotlib.pyplot as plt

plt.figure(dpi=380)
# color=['#76a5af', '#134f5c']
# color=['#f4cccc', '#0c343d']
# color=['#a4c2f4', '#1c4587']
# color=['#e06666', '#d9d9d9']
# color=['#e06666', '#434343']
# color=['#b6d7a8','#6aa84f']
# Out:
# 2:1: W293 blank line contains whitespace
# 3:22: E231 missing whitespace after ','
# 3:25: E231 missing whitespace after ','
# 3:28: E231 missing whitespace after ','
# 3:31: E231 missing whitespace after ','
# 3:38: E231 missing whitespace after ','
# 11:1: W293 blank line contains whitespace
# 13:24: E251 unexpected spaces around keyword / parameter equals
# 14:49: E231 missing whitespace after ','
# 14:52: E231 missing whitespace after ','
# 14:80: E501 line too long (155 > 79 characters)
# 14:88: E231 missing whitespace after ','
# 14:122: E231 missing whitespace after ','
# 18:1: W293 blank line contains whitespace
# 19:1: E305 expected 2 blank lines after class or function definition, found 1
# 19:1: E402 module level import not at top of file
# 20:16: E251 unexpected spaces around keyword / parameter equals
# 21:5: E116 unexpected indentation (comment)
# 21:5: E265 block comment should start with '# '
# 22:5: E116 unexpected indentation (comment)
# 22:5: E265 block comment should start with '# '
# 23:5: E116 unexpected indentation (comment)
# 23:5: E265 block comment should start with '# '
# 24:5: E116 unexpected indentation (comment)
# 24:5: E265 block comment should start with '# '
# 25:5: E116 unexpected indentation (comment)
# 25:5: E265 block comment should start with '# '
# 26:5: E116 unexpected indentation (comment)
# 26:5: E265 block comment should start with '# '

# %%
df = df3
x1 = "beer_servings"
x2 = "spirit_servings"
x3 = "wine_servings"
by = "continent"
title = "Alcohol consumption by continents"
x_title = "The level o consumptions"

PKO = N_plot3(df, x1, x2, x3, by, title, x_title)
PKO.plot()
# Out:
# 1:3: E225 missing whitespace around operator
# 2:3: E225 missing whitespace around operator
# 3:3: E225 missing whitespace around operator
# 4:3: E225 missing whitespace around operator
# 5:3: E225 missing whitespace around operator
# 9:17: E231 missing whitespace after ','
# 9:20: E231 missing whitespace after ','
# 9:23: E231 missing whitespace after ','
# 9:26: E231 missing whitespace after ','
# 9:29: E231 missing whitespace after ','

# %% [markdown]
# ## World Happiness Report
# Source of data: https://data.world/promptcloud/world-happiness-report-2019

# %%
df4 = pd.read_csv("/media/wojciech/D6DE33C1DE339927/1A/WorldHappinessReport.csv")
df4.head(3)
# Out:
#   Unnamed: 0      Country                           Region  Happiness Rank  \
# 0          0  Afghanistan                    Southern Asia           153.0
# 1          1      Albania       Central and Eastern Europe            95.0
# 2          2      Algeria  Middle East and Northern Africa            68.0
#
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            3.575                   0.31982  0.30285
# 1            4.959                   0.87867  0.80434
# 2            5.605                   0.93929  1.07772
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.30335  0.23414                        0.09719
# 1                   0.81325  0.35733                        0.06413
# 2                   0.61766  0.28579                        0.17383
#
#    Generosity  Dystopia Residual    Year
# 0     0.36510            1.95210  2015.0
# 1     0.14272            1.89894  2015.0
# 2     0.07822            2.43209  2015.0
# 1:80: E501 line too long (81 > 79 characters)

# %%
df4["Year"].value_counts()
# Out:
# 2017.0    164
# 2016.0    164
# 2015.0    164
# Name: Year, dtype: int64

# %%
CC = df4[df4["Year"] == 2017]
CC.head(3)
# Out:
#     Unnamed: 0      Country                           Region  Happiness Rank  \
# 330        330  Afghanistan                    Southern Asia           141.0
# 331        331      Albania       Central and Eastern Europe           109.0
# 332        332      Algeria  Middle East and Northern Africa            53.0
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 330            3.794                  0.401477  0.581543
# 331            4.644                  0.996193  0.803685
# 332            5.872                  1.091864  1.146217
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 330                  0.180747  0.106180                       0.061158
# 331                  0.731160  0.381499                       0.039864
# 332                  0.617585  0.233336                       0.146096
#
#      Generosity  Dystopia Residual    Year
# 330    0.311871           2.150801  2017.0
# 331    0.201313           1.490442  2017.0
# 332    0.069437           2.567604  2017.0
# 1:21: E225 missing whitespace around operator

# %%
df = CC
x1 = "Freedom"
x2 = "Trust (Government Corruption)"
by = "Region"
title = "World Happiness Report"
x_title = "Indicator"

ZNP = N_plot(df, x1, x2, by, title, x_title)
ZNP.plot()
# Out:
# 1:3: E225 missing whitespace around operator
# 2:3: E225 missing whitespace around operator
# 3:3: E225 missing whitespace around operator
# 4:3: E225 missing whitespace around operator
# 8:16: E231 missing whitespace after ','
# 8:19: E231 missing whitespace after ','
# 8:22: E231 missing whitespace after ','
# 8:25: E231 missing whitespace after ','

# %% [markdown]
# ## Banking marketing
# Analysis of the categorical results.
# Source of data: https://archive.ics.uci.edu/ml/machine-learning-databases/00222/

# %%
df5 = pd.read_csv("/media/wojciech/D6DE33C1DE339927/1A/bank.csv")
df5.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  age          job  marital          education  \
# 0           0             0   44  blue-collar  married           basic.4y
# 1           1             1   53   technician  married            unknown
# 2           2             2   28   management   single  university.degree
#
#    default housing loan   contact  ... campaign pdays  previous     poutcome  \
# 0  unknown     yes   no  cellular  ...        1   999         0  nonexistent
# 1       no      no   no  cellular  ...        1   999         0  nonexistent
# 2       no     yes   no  cellular  ...        3     6         2      success
#
#    emp_var_rate  cons_price_idx cons_conf_idx  euribor3m  nr_employed  y
# 0           1.4          93.444         -36.1      4.963       5228.1  0
# 1          -0.1          93.200         -42.0      4.021       5195.8  0
# 2          -1.7          94.055         -39.8      0.729       4991.6  1
#
# [3 rows x 23 columns]

# %%
FF = df5.pivot_table(
    index=["Unnamed: 0", "marital"], columns="y", values="age"
).reset_index()
FF.head()
# Out:
# y  Unnamed: 0  marital     0     1
# 0           0  married  44.0   NaN
# 1           1  married  53.0   NaN
# 2           2   single   NaN  28.0
# 3           3  married  39.0   NaN
# 4           4  married   NaN  55.0

# %%
df = FF
x1 = 0
x2 = 1
by = "marital"
title = "Customer age structure"
x_title = "customer age"

KLD = N_plot(df, x1, x2, by, title, x_title)
KLD.plot()
# Out:
# 8:16: E231 missing whitespace after ','
# 8:19: E231 missing whitespace after ','
# 8:22: E231 missing whitespace after ','
# 8:25: E231 missing whitespace after ','
# 8:31: E231 missing whitespace after ','
